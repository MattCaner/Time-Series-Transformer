# %%
import pandas as pd

# %%
file = open('Avg_data.csv','r')
df = pd.read_csv(file)
df = df.drop(columns=['Date', 'Day of the week [-]','Temp [C]','Humidity [%]','Wind [m/s]','Clouds [1/8]'],axis = 1)

file2 = open('sentiment.csv','r')
df2 = pd.read_csv(file2)

df.reset_index(drop=True, inplace=True)
df2.reset_index(drop=True, inplace=True)

result = pd.concat( [df, df2], axis=1)
df2
# Out:
# array([[<Axes: xlabel='SUM - Entry [GWh/d]', ylabel='SUM - Entry [GWh/d]'>,
#         <Axes: xlabel='SUM - Exit [GWh/d]', ylabel='SUM - Entry [GWh/d]'>,
#         <Axes: xlabel='SUM - Exit t-1d [GWh/d]', ylabel='SUM - Entry [GWh/d]'>,
#         <Axes: xlabel='Storage t-1d [GWh/d]', ylabel='SUM - Entry [GWh/d]'>,
#         <Axes: xlabel='Storage [GWh/d]', ylabel='SUM - Entry [GWh/d]'>,
#         <Axes: xlabel='negative', ylabel='SUM - Entry [GWh/d]'>,
#         <Axes: xlabel='positive', ylabel='SUM - Entry [GWh/d]'>,
#         <Axes: xlabel='neutral', ylabel='SUM - Entry [GWh/d]'>,
#         <Axes: xlabel='negative_std', ylabel='SUM - Entry [GWh/d]'>,
#         <Axes: xlabel='positive_std', ylabel='SUM - Entry [GWh/d]'>,
#         <Axes: xlabel='neutral_std', ylabel='SUM - Entry [GWh/d]'>],
#        [<Axes: xlabel='SUM - Entry [GWh/d]', ylabel='SUM - Exit [GWh/d]'>,
#         <Axes: xlabel='SUM - Exit [GWh/d]', ylabel='SUM - Exit [GWh/d]'>,
# ...
